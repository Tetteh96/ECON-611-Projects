# %% [markdown]
# # CHAPTER ONE
#
# ## Introduction
#
# Strong economic growth in some OECD countries over the 1990s, most notably in the United States, led many commentators to speculate that a "new economy" had emerged, largely driven by the spread of information and communication technology (IGT). In particular, economic performance in the United States included a combination of strong output and productivity growth, together with falling unemployment and low inflation. These patterns were all the more surprising for a country already at the technology frontier in many industries and had no similar counterpart in other affluent OECD economies. Indeed, over the 1990s, large continental European countries, and Japan,. experienced slow economic growth and rising, or persistently high unemployment.
#
# The GDP growth rate in OECD countries has fluctuated over the years, but it is still one of the most important measures of economic performance. Numerous variables, including inflation, unemployment rates, and governmental policies, are found to have an impact on the GDP growth rate. There hasn't been enough research done to completely understand the factors that affect the rate of GDP growth (economic growth) in the US. In order to determine the factors that influence the economic growth (GDP growth rate), it is necessary to look into the relationship between these factors and economic growth in OECD countries.
#
# To this end, we have formulated null and alternative hypotheses to achieve the study's objective. By testing these hypotheses using empirical data, we hope to contribute to the understanding of the factors that influence economic growth in OECD countries and to inform policy decisions related to trade policy.
#
# - Null hypothesis($H_0$): There are no significant factors that affect economic growth in OECD countries.
#
# - Alternative hypothesis($H_A$): There are significant factors that affect economic growth in OECD countries.
#
# The study also seeks to answer the following questions based on the objective of the study:
#
# 1.	What are the factors that impact economic growth in OECD countries?
#
# 2.	To what extent do these factors affect economic growth in OECD countries?

# %% [markdown]
# # CHAPTER TWO
#
# ## Literature Review
#
# ### Theoretical Literature
#
# According to conventional trade theory, specialisation, investments in innovation, increased productivity, and better resource allocation are some ways that trade benefits nations (Zahonogo 2016). This is also evident in the Ricardian– Heckscher–Ohlin theoretical model (Leamer and Levinsohn 1995). International trade openness can therefore improve output since it allows nations to more effectively allocate resources based on their comparative advantages. According to the theory of international trade, trade benefits can come from a variety of fundamental factors, including differences in comparative advantage and a rise in international trade globally (Yanikkaya 2003). The idea of comparative advantage states that because countries can import goods and services rather than investing heavily in domestic production, international trade encourages countries to employ resources more effectively. This demonstrates that imports are equally crucial to economic activity as exports. In other words, imports and exports are two elements that work in tandem and are mutually dependent. As a result, each country's trade openness provides a clear indication of its participation in international trade. The value of exports and imports in relation to GDP is shown by this indicator (Yanikkaya 2003; Fetahi-Vehapi et al. 2015; Zahonogo 2016).
#
# The neoclassical growth theory, which is based on Solow's (1957) model, is one of the first ideas that can be used to explain the relationship between Trade Openness and Economic Growth. This theory makes the assumption that external technological advancement has a long-term, major impact on Economic Growth. Therefore, if trade openness fosters technical advancement, it may have a long-term effect on economic growth. The neoclassical growth theory, in general, has a significant shortcoming since it does not offer a theoretical foundation that suggests that commercial openness can foster technical advancement.
#
#
# ### Empirical Literature
#
# Kong et al. (2021) investigated the impact of exchange rate fluctuations on China's quality of economic growth and Chinese opening up between 1994 and 2018. According to the study, there is a long-term, steady correlation between opening up and the calibre of economic growth. They argued that trade openness can greatly improve the long- and short-term quality of economic growth. They also argued that the quality of economic growth could be maintained through automatic adjustment when the short-term volatility departed from the long-term equilibrium. There was significant geographical variation and non-linear threshold characteristics in the beneficial effect of trade openness on the quality of economic growth.
#
# In order to look at the factors that contribute to economic growth, Parash (2015) used Ordinary Least Squares regressions for the years 2010, 2005, 2000, and 1995. To determine whether the patterns in the variables are consistent throughout time, it then compares them. In all historical periods examined, it was discovered that the volume of exports and the development of natural resources have a favourable effect on economic growth in developing nations. Additionally, it discovers that increased investment and a longer life expectancy had a favourable effect on economic growth, however this finding was only true for two of the three time periods. These results are in line with other studies, and several of these factors affect economic growth in both industrialised and developing nations.
#
# Nguyen and Bui (2021) looked at the nonlinear relationship between trade openness and economic growth in the Asean-6 nations (Indonesia, Malaysia, Thailand, Singapore, Philippines, and Vietnam). The fixed-effect panel threshold approach was used by the authors to estimate the research model in order to meet the predetermined research objectives. According to the study, trade openness has a nonlinear effect on economic growth and has two threshold values. The study's findings demonstrated that high levels of trade openness (beyond the threshold value) without the addition of other complementing policies do not promote high-efficiency economic growth.
#
# With data spanning the years 1993 to 2016, Raghutla (2020) examined the effect of trade openness on economic growth in a panel of five developing market economies. The empirical findings supported the long-run relationships between trade openness, economic growth, financial development, inflation, labour force, and technology based on panel estimation methods, whereas the results of long-run elasticities show that trade openness has a significant positive impact on economic growth. According to the heterogeneous panel non-causality tests, there is a short-term unidirectional causal relationship between economic growth and trade openness as well as between economic growth and financial development. There is also a bidirectional relationship between economic growth and inflation. The results indicated that in these five emerging market economies, trade openness significantly contributes to both economic development and growth.

# %% [markdown]
# # CHAPTER THREE
#
# ## Methodology
# ### Data and Variables
#
# Data from 1970 through 2021 were used for the study. This study mainly used secondary data from the World Bank. The variables are briefly explained as follows:
#
# Economic growth: the annual increase or improvement in the real per capita income (real GDP per capita or output per person) in an economy. In this study, annual real GDP is the monetary value of all final goods and services at market prices in US dollars with year 2010 as the base year. This data is sourced from World Bank.
#
# Trade openness: Trade between two or more countries. It is measured in this study as total trade expressed as percent of GDP. This data is sourced from World Bank.
#
# Foreign Direct Investment: Foreign direct investment are the net inflows of investment to acquire a lasting management interest (10 percent or more of voting stock) in an enterprise operating in an economy other than that of the investor. It is the sum of equity capital, reinvestment of earnings, other long-term capital, and short-term capital as shown in the balance of payments.
#
# Government Spending: government final consumption expenditure formerly known as general government consumption. It includes all government current expenditures for purchases of goods and services including compensation of employees and most expenditure on national defense and security. It excludes government military expenditures that are part of government capital formation. This data is sourced from World Bank in current U.S. dollars.
#
# Population Growth: Annual population growth rate for year t is the exponential rate of growth of midyear population from year t-1 to t, expressed as a percentage.
#
# Inflation: Inflation as measured by the consumer price index reflects the annual percentage change in the cost to the average consumer of acquiring a basket of goods and services that may be fixed or changed at specified intervals, such as yearly.
#
#
# ### Model Specification
#
# The study used the OLS to estimate the impact of trade openness on economic growth. The study uses historical data from 1970-2021 (51 years) of the United States. The OLS can be used to derive unbiased and consistent estimates of parameters. The dataset was logged and difference at first levels
#
# The ordinary linear econometric model that will be used in this study is as follows: log_GDP per capita(-1)
#
#
# $log{\Delta}\_GDP per capita = \beta_0 + \beta_1 log{\Delta}\_FDI(NET) + \beta_2 log{\Delta}\_Trade(\% of GDP) + \beta_3 log{\Delta}\_CPI\_Inflation + \beta_4 log{\Delta}\_Pop\_growth + \beta_5 log{\Delta}\_GOVT\_EXP + \beta_6 log{\Delta}\_GDP per capita(-1) + \mu_i$
#
#
#
# In this equation, the dependent variable($log{\Delta}\_GDP per capita$) is economic growth (GDP per capita). $\beta_0$ is the intercept of the equation and vectors of the equation are $\beta_1$, $\beta_2$, $\beta_3$, $\beta_4$, $\beta_5$ and $\beta_6$ respectively. $log{\Delta}\_Trade(\% of GDP)$ denotes the trade openness, $log{\Delta}\_CPI\_Inflation$ represents CPI inflation in the United States, $log{\Delta}\_FDI(NET)$ represents net foreign direct investment, $log{\Delta}\_Pop\_growth$, represents population growth rate in United States overtime, $log{\Delta}\_GOVT\_EXP$ denotes total government expenditure in the United States over the years\ and $log{\Delta}\_GDP per capita(-1)$ denotes the previous year's economic growth (GDP pre capita).

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

import warnings
warnings.filterwarnings('ignore')

# %%
# Set the country code
country_code = ['AUS', 'AUT', 'BEL', 'CAN', 'CHL', 'COL', 'CRI',
                'CZE', 'DNK', 'EST', 'FIN', 'FRA', 'DEU',
                'GRC', 'HUN', 'ISL', 'IRL', 'ISR', 'ITA', 'JPN', 
                'KOR', 'LVA', 'LTU', 'LUX', 'MEX', 'NLD', 'NZL', 'NOR',
                 'POL', 'PRT', 'SVK', 'SVN', 'ESP', 'SWE',
                'CHE', 'TUR', 'GBR', 'USA']

# Set the indicators
indicators = {
    'BX.KLT.DINV.WD.GD.ZS': 'FDI_NET',
    'NE.TRD.GNFS.ZS': 'TradeOpen',
    'NY.GDP.PCAP.CD': 'GDP_per_capita',
    #'FP.CPI.TOTL': 'CPI',
    #'SP.POP.GROW': 'Pop_growth',
    'NE.CON.GOVT.ZS': 'GOVT_EXP',
}

# Get the data
data = wbdata.get_dataframe(indicators, country=country_code, convert_date=True)

# Reorder the rows with 1960 as the first index
data = data.reindex(index=data.index[::-1])

# Sort the data by country and year
data = data.sort_index(level=['country', 'date'])

# Slice the data to only include years 1990 to 2019
idx = pd.IndexSlice
data = data.loc[idx[:, '1990-01-01':'2019-01-01'], :]

# %%
data
# Out:
#                            FDI_NET  TradeOpen  GDP_per_capita   GOVT_EXP
# country       date
# Australia     1990-01-01  2.715756  32.152317    18249.709485  17.641361
#               1991-01-01  0.801279  32.188568    18860.581591  18.631483
#               1992-01-01  1.518103  33.043854    18624.555084  19.495664
#               1993-01-01  1.701950  35.399057    17700.115556  19.375781
#               1994-01-01  1.381151  36.458496    18129.790720  18.812698
# ...                            ...        ...             ...        ...
# United States 2015-01-01  2.809148  27.812234    56762.729452  14.330331
#               2016-01-01  2.537498  26.586999    57866.744934  14.244944
#               2017-01-01  1.955211  27.279161    59907.754261  13.998629
#               2018-01-01  1.045704  27.610379    62823.309438  13.962519
#               2019-01-01  1.472075  26.451949    65120.394663  14.072225
#
# [1140 rows x 4 columns]

# %%
data.isna().sum()
# Out:
# FDI_NET           44
# TradeOpen         31
# GDP_per_capita    26
# GOVT_EXP          31
# dtype: int64

# %%
data.isna().mean()
# Out:
# FDI_NET           0.038596
# TradeOpen         0.027193
# GDP_per_capita    0.022807
# GOVT_EXP          0.027193
# dtype: float64

# %% [markdown]
# #### Taking Log Transformation of the columns

# %%
for col in data.columns:
    new_col = 'log_' + col
    data[new_col] = data[col].apply(np.log)

# %%
data = data.loc[:, data.columns.str.contains('log')]

# %%
data = data.groupby('country').apply(lambda x: x.dropna())

# %%
# Reset the index and drop the first level
data = data.reset_index(level=0, drop=True)

# %%
data
# Out:
#                           log_FDI_NET  log_TradeOpen  log_GDP_per_capita
# country       date
# Australia     1990-01-01     0.999070       3.470485            9.811904  \
#               1991-01-01    -0.221546       3.471611            9.844829
#               1992-01-01     0.417461       3.497836            9.832236
#               1993-01-01     0.531775       3.566685            9.781326
#               1994-01-01     0.322917       3.596175            9.805312
# ...                               ...            ...                 ...
# United States 2015-01-01     1.032881       3.325476           10.946635
#               2016-01-01     0.931178       3.280422           10.965898
#               2017-01-01     0.670498       3.306123           11.000561
#               2018-01-01     0.044690       3.318192           11.048081
#               2019-01-01     0.386673       3.275330           11.083993
#
#                           log_GOVT_EXP
# country       date
# ...

# %% [markdown]
# ### Descriptive statistics

# %%
data.describe().T.round(3)
# Out:
#                      count   mean    std    min    25%     50%     75%     max
# log_FDI_NET         1021.0  0.887  1.289 -7.199  0.298   0.970   1.582   4.460
# log_TradeOpen       1021.0  4.270  0.514  2.761  3.969   4.238   4.607   5.934
# log_GDP_per_capita  1021.0  9.891  0.882  7.291  9.375  10.054  10.567  11.725
# log_GOVT_EXP        1021.0  2.895  0.236  2.094  2.787   2.938   3.048   3.336

# %% [markdown]
# - log_FDI_NET: The mean value of log_FDI_NET is 0.887, which indicates that, on average, FDI (Foreign Direct Investment) is positive. However, the standard deviation of 1.289 suggests that there is a considerable amount of variation in FDI. The minimum value of -7.199 suggests that there may be some negative FDI values, which is unusual. The 25th percentile is 0.298, indicating that 25% of the observations have values less than this. The median value is 0.970, which is higher than the mean, indicating a slightly right-skewed distribution. The 75th percentile is 1.582, suggesting that 75% of the observations have values less than this. The maximum value is 4.460, indicating that there may be some extreme values in the dataset.
#
#
# - log_TradeOpen: The mean value of log_TradeOpen is 4.270, indicating that, on average, countries have a relatively open trade policy. The standard deviation of 0.514 suggests that there is not much variation in the data. The minimum value is 2.761, indicating that some countries may have relatively closed trade policies. The 25th percentile is 3.969, indicating that 25% of the observations have values less than this. The median value is 4.238, which is slightly lower than the mean, indicating a slightly left-skewed distribution. The 75th percentile is 4.607, suggesting that 75% of the observations have values less than this. The maximum value is 5.934, indicating that some countries may have very open trade policies.
#
#
# - log_GDP_per_capita: The mean value of log_GDP_per_capita is 9.891, indicating that the average GDP per capita of the sample is quite high. The standard deviation of 0.882 suggests that there is a considerable amount of variation in the data. The minimum value is 7.291, indicating that some countries have very low GDP per capita. The 25th percentile is 9.375, indicating that 25% of the observations have values less than this. The median value is 10.054, which is higher than the mean, indicating a slightly right-skewed distribution. The 75th percentile is 10.567, suggesting that 75% of the observations have values less than this. The maximum value is 11.725, indicating that some countries have very high GDP per capita.
#
#
# - log_GOVT_EXP: The mean value of log_GOVT_EXP is 2.893, indicating that, on average, the government expenditure is relatively low. The standard deviation of 0.236 suggests that there is not much variation in the data. The minimum value is 2.094, indicating that some countries may have very low government expenditure. The 25th percentile is 2.787, indicating that 25% of the observations have values less than this. The median value is 2.938, which is higher than the mean, indicating a slightly right-skewed distribution. The 75th percentile is 3.048, suggesting that 75% of the observations have values less than this. The maximum value is 3.336, indicating that some countries may have relatively high government expenditure.

# %%
skewness = data.skew()
skewness
# Out:
# log_FDI_NET          -1.041312
# log_TradeOpen         0.043824
# log_GDP_per_capita   -0.648131
# log_GOVT_EXP         -0.847168
# dtype: float64

# %% [markdown]
# - log_FDI_NET: -1.041312
#
# This indicates that the distribution of log_FDI_NET is skewed to the left, with a long tail on the negative side. This means that there are more values on the positive side, with some extreme negative values.
#
# - log_TradeOpen: 0.043824
#
# The skewness of log_TradeOpen is close to zero, indicating that its distribution is almost symmetric. This means that the values are more or less evenly distributed around the mean.
#
# - log_GDP_per_capita: -0.648131
#
# The skewness of log_GDP_per_capita is negative, indicating that the distribution is skewed to the left. This means that there are more values on the positive side, with some extreme negative values.
#
# - log_GOVT_EXP: -0.847168
#
# The skewness of log_GOVT_EXP is negative, indicating that the distribution is skewed to the left. This means that there are more values on the positive side, with some extreme negative values.

# %%
kurtosis = data.kurt()
kurtosis
# Out:
# log_FDI_NET           4.762864
# log_TradeOpen         0.354073
# log_GDP_per_capita   -0.159263
# log_GOVT_EXP          0.332913
# dtype: float64

# %% [markdown]
# - log_FDI_NET: 4.762864
#
# The kurtosis of log_FDI_NET is significantly higher than 3, indicating that the distribution is very peaked and has heavy tails. This suggests that there are many extreme values that are far from the mean.
#
# - log_TradeOpen: 0.354073
#
# The kurtosis of log_TradeOpen is slightly higher than 3, but not by much. This indicates that the distribution is somewhat peaked, but not to the same degree as log_FDI_NET.
#
# - log_GDP_per_capita: -0.159263
#
# The kurtosis of log_GDP_per_capita is negative, indicating that the distribution is flatter than a normal distribution. This suggests that there are fewer extreme values than in a normal distribution, and that the values are more concentrated around the mean.
#
# - log_GOVT_EXP: 0.332913
#
# The kurtosis of log_GOVT_EXP is slightly higher than 3, indicating that the distribution is somewhat peaked, but not to the same degree as log_FDI_NET.

# %%
corr = data.corr().round(3)
corr
# Out:
#                     log_FDI_NET  log_TradeOpen  log_GDP_per_capita
# log_FDI_NET               1.000          0.542               0.036  \
# log_TradeOpen             0.542          1.000               0.141
# log_GDP_per_capita        0.036          0.141               1.000
# log_GOVT_EXP              0.070          0.204               0.323
#
#                     log_GOVT_EXP
# log_FDI_NET                0.070
# log_TradeOpen              0.204
# log_GDP_per_capita         0.323
# log_GOVT_EXP               1.000

# %% [markdown]
# - log_FDI_NET and log_TradeOpen have a moderately positive correlation of 0.542, suggesting that they may be related. This could indicate that a change in log_TradeOpen could be associated with a change in log_FDI_NET, or vice versa.
#
# - log_GDP_per_capita has a weak positive correlation of 0.036 with log_FDI_NET, indicating a minimal relationship between the two variables.
#
# - log_GOVT_EXP has a weak positive correlation of 0.086 with log_FDI_NET, suggesting a minor relationship between the two variables.

# %%
fig, ax = plt.subplots(figsize = (10, 8))

# create a heatmap using seaborn
heatmap = sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, ax =ax)

# set rotation for x-axis and y-axis tick labels
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)

# set plot title
plt.title('Correlation')

# show the plot
plt.show()

# %%
data_plot = data.reset_index()
sns.pairplot(data_plot, hue=data_plot.columns[0], palette='bright')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (10, 6))

# Plot the data
data.groupby(level='date').mean().plot(ax = ax)

# Set the title and axis labels
ax.set_title('World Bank Indicators')
ax.set_xlabel('Year')
ax.set_ylabel('Economic Indicator Value')

# Show the plot
plt.show()

# %% [markdown]
# ### Fixed Effects Model

# %%
from linearmodels.panel import PanelOLS
import statsmodels.api as sm


exog_vars = ['log_FDI_NET', 'log_TradeOpen', 'log_GOVT_EXP']
exog = sm.add_constant(data[exog_vars])
endog = data['log_GDP_per_capita']

# Fit a fixed effects model
mod = PanelOLS(endog, exog, entity_effects=True, time_effects=False)
res_fe = mod.fit(cov_type='clustered', cluster_entity=True)
print(res_fe.summary)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     log_GDP_per_capita   R-squared:                        0.0810
# Estimator:                   PanelOLS   R-squared (Between):              0.1416
# No. Observations:                 945   R-squared (Within):               0.0810
# Date:                Fri, May 12 2023   R-squared (Overall):              0.0846
# Time:                        20:33:25   Log-likelihood                    452.26
# Cov. Estimator:             Clustered
#                                         F-statistic:                      26.577
# Entities:                          38   P-value                           0.0000
# Avg Obs:                       24.868   Distribution:                   F(3,904)
# Min Obs:                       13.000
# Max Obs:                       28.000   F-statistic (robust):             12.908
#                                         P-value                           0.0000
# ...

# %% [markdown]
# The above PanelOLS estimation results show the impact of three variables, log_FDI_NET (net foreign direct investment), log_TradeOpen (trade openness), and log_GOVT_EXP (government expenditure), on log_GDP_per_capita (GDP per capita) in OECD countries. The estimation is based on a fixed effects model, with entity-specific intercepts included.
#
# The R-squared value of 0.0810 indicates that the three variables explain around 8.1% of the variation in GDP per capita. The R-squared (Between) value of 0.1416 indicates that 14.16% of the variation is explained by entity-specific characteristics, while the R-squared (Within) and R-squared (Overall) values are equal to the R-squared value.
#
# The F-statistic of 26.577 with a p-value of 0.0000 indicates that the three variables jointly have a significant impact on GDP per capita. The robust F-statistic of 12.908 with a p-value of 0.0000 shows that the estimated coefficients are reliable even when the errors are heteroscedastic or have autocorrelation.
#
# The F-test for poolability has a value of 1.5390 and a corresponding p-value of 0.0220, indicating that there is some evidence against the hypothesis that all entities have the same intercept and slopes. The included effects in the model are only for entity.
#
# The coefficient for log_FDI_NET is 0.0057, with a standard error of 0.0077 and a t-statistic of 0.7427. The p-value for this coefficient is 0.4579, indicating that the relationship between log_FDI_NET and log_GDP_per_capita is not statistically significant at conventional levels.
#
# The coefficient for log_TradeOpen is -0.4340, with a standard error of 0.0933 and a t-statistic of -4.6500. The p-value for this coefficient is 0.0000, indicating that there is a statistically significant negative relationship between log_TradeOpen and log_GDP_per_capita.
#
# Finally, the coefficient for log_GOVT_EXP is -0.6295, with a standard error of 0.1203 and a t-statistic of -5.2321. The p-value for this coefficient is 0.0000, indicating that there is a statistically significant negative relationship between log_GOVT_EXP and log_GDP_per_capita.

# %% [markdown]
# #### with time effects (two-way fixed effects model)

# %%
# Fit a fixed effects model
mod = PanelOLS(endog, exog, entity_effects=True, time_effects=True)
res_te_fe = mod.fit(cov_type='clustered', cluster_entity=True)
print(res_te_fe.summary)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     log_GDP_per_capita   R-squared:                        0.3366
# Estimator:                   PanelOLS   R-squared (Between):             -0.0274
# No. Observations:                 945   R-squared (Within):               0.0084
# Date:                Fri, May 12 2023   R-squared (Overall):              0.0070
# Time:                        20:33:26   Log-likelihood                    937.64
# Cov. Estimator:             Clustered
#                                         F-statistic:                      148.33
# Entities:                          38   P-value                           0.0000
# Avg Obs:                       24.868   Distribution:                   F(3,877)
# Min Obs:                       13.000
# Max Obs:                       28.000   F-statistic (robust):             25.315
#                                         P-value                           0.0000
# ...

# %%
# #tedata = data.set_index(['country','date'])
# #from pandas.stats import plm

# plm.PanelOLS(data['log_FDI_NET'],data[['log_CPI_Inflation_rate', 'log_TradeOpen', 'log_GOVT_EXP']],entity_effects=True)

# %%
data['Predicted GDP_per_capita'] = res_fe.predict()
data['Residuals'] = res_fe.resids

# %%
data['Predicted GDP_per_capita(TE)'] = res_te_fe.predict()
data['Residuals(TE)'] = res_te_fe.resids

# %%
data
# Out:
#                           log_FDI_NET  log_TradeOpen  log_GDP_per_capita
# country       date
# Australia     1992-01-01    -0.581609       0.027351            0.020332  \
#               1993-01-01     0.753320       0.095074           -0.063503
#               1994-01-01    -0.094544       0.098339           -0.026924
#               1995-01-01     0.750351       0.063151            0.144251
#               1996-01-01    -0.194295       0.047603            0.194399
# ...                               ...            ...                 ...
# United States 2015-01-01     0.495997      -0.075800            0.063110
#               2016-01-01     0.569999      -0.120708            0.048560
#               2017-01-01    -0.362383      -0.019353            0.053926
#               2018-01-01    -0.886488       0.037769            0.082183
#               2019-01-01    -0.283825      -0.030793            0.083432
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10, 6))

data[['log_GDP_per_capita', 'Predicted GDP_per_capita', 'Predicted GDP_per_capita(TE)']].groupby(level='date').mean().plot(ax = ax)

ax.set_title('Observed GDP Per Capita vrs Predicted GDP Per Capita in OECD Countries')
ax.set_ylabel('Per capita (in billions)')
# Out:
# Text(0, 0.5, 'Per capita (in billions)')

# %% [markdown]
# #### one-way fixed effects Residual Plot

# %%
# plot histogram of residuals
fig, ax = plt.subplots(figsize = (12, 8))
data['Residuals'].plot.hist(bins = 16, ax = ax)

# plot vertical line for mean of residuals
ax.axvline(data['Residuals'].mean(), ls = '--', linewidth = 5, color = 'k')

# %% [markdown]
# #### two-way fixed effects Residual Plot

# %%
# plot histogram of residuals
fig, ax = plt.subplots(figsize = (12, 8))
data['Residuals(TE)'].plot.hist(bins = 16, ax = ax)

# plot vertical line for mean of residuals
ax.axvline(data['Residuals(TE)'].mean(), ls = '--', linewidth = 5, color = 'k')
