# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

import warnings
warnings.filterwarnings('ignore')

# %%
# Set the country code
country_code = ['AUS', 'AUT', 'BEL', 'CAN', 'CHL', 'COL', 'CRI',
                'CZE', 'DNK', 'EST', 'FIN', 'FRA', 'DEU',
                'GRC', 'HUN', 'ISL', 'IRL', 'ISR', 'ITA', 'JPN', 
                'KOR', 'LVA', 'LTU', 'LUX', 'MEX', 'NLD', 'NZL', 'NOR',
                 'POL', 'PRT', 'SVK', 'SVN', 'ESP', 'SWE',
                'CHE', 'TUR', 'GBR', 'USA']

# Set the indicators
indicators = {
    'BX.KLT.DINV.WD.GD.ZS': 'FDI_NET',
    'NE.TRD.GNFS.ZS': 'TradeOpen',
    'NY.GDP.PCAP.CD': 'GDP_per_capita',
    'FP.CPI.TOTL.ZG': 'CPI_Inflation_rate',
    #'SP.POP.GROW': 'Pop_growth',
    'NE.CON.GOVT.ZS': 'GOVT_EXP'
}

# Get the data
data = wbdata.get_dataframe(indicators, country=country_code, convert_date=True)

# Reorder the rows with 1960 as the first index
data = data.reindex(index=data.index[::-1])

# Sort the data by country and year
data = data.sort_index(level=['country', 'date'])

# Slice the data to only include years 1990 to 2019
idx = pd.IndexSlice
data = data.loc[idx[:, '1990-01-01':'2019-01-01'], :]

# %%
data
# Out:
#                            FDI_NET  TradeOpen  GDP_per_capita
# country       date
# Australia     1990-01-01  2.715756  32.152317    18249.709485  \
#               1991-01-01  0.801279  32.188568    18860.581591
#               1992-01-01  1.518103  33.043854    18624.555084
#               1993-01-01  1.701950  35.399057    17700.115556
#               1994-01-01  1.381151  36.458496    18129.790720
# ...                            ...        ...             ...
# United States 2015-01-01  2.809148  27.812234    56762.729452
#               2016-01-01  2.537498  26.586999    57866.744934
#               2017-01-01  1.955211  27.279161    59907.754261
#               2018-01-01  1.045704  27.610379    62823.309438
#               2019-01-01  1.472075  26.451949    65120.394663
#
#                           CPI_Inflation_rate   GOVT_EXP
# country       date
# Australia     1990-01-01            7.333022  17.641361
#               1991-01-01            3.176675  18.631483
# ...

# %%
data.isna().sum()
# Out:
# FDI_NET               44
# TradeOpen             31
# GDP_per_capita        26
# CPI_Inflation_rate    11
# GOVT_EXP              31
# dtype: int64

# %%
data.isna().mean()
# Out:
# FDI_NET               0.038596
# TradeOpen             0.027193
# GDP_per_capita        0.022807
# CPI_Inflation_rate    0.009649
# GOVT_EXP              0.027193
# dtype: float64

# %% [markdown]
# #### Taking Log Transformation of the columns

# %%
for col in data.columns:
    new_col = 'log_' + col
    data[new_col] = data[col].apply(np.log)

# %%
data = data.loc[:, data.columns.str.contains('log')]

# %%
data = data.groupby('country').apply(lambda x: x.dropna())

# %%
# Reset the index and drop the first level
data = data.reset_index(level=0, drop=True)

# %%
data
# Out:
#                           log_FDI_NET  log_TradeOpen  log_GDP_per_capita
# country       date
# Australia     1990-01-01     0.999070       3.470485            9.811904  \
#               1991-01-01    -0.221546       3.471611            9.844829
#               1992-01-01     0.417461       3.497836            9.832236
#               1993-01-01     0.531775       3.566685            9.781326
#               1994-01-01     0.322917       3.596175            9.805312
# ...                               ...            ...                 ...
# United States 2015-01-01     1.032881       3.325476           10.946635
#               2016-01-01     0.931178       3.280422           10.965898
#               2017-01-01     0.670498       3.306123           11.000561
#               2018-01-01     0.044690       3.318192           11.048081
#               2019-01-01     0.386673       3.275330           11.083993
#
#                           log_CPI_Inflation_rate  log_GOVT_EXP
# ...

# %% [markdown]
# ### Descriptive statistics

# %%
data.describe().T.round(3)
# Out:
#                         count   mean    std    min    25%     50%     75%
# log_FDI_NET             965.0  0.909  1.237 -6.524  0.318   0.975   1.581  \
# log_TradeOpen           965.0  4.272  0.501  2.761  3.969   4.238   4.595
# log_GDP_per_capita      965.0  9.868  0.890  7.291  9.349  10.047  10.558
# log_CPI_Inflation_rate  965.0  0.999  1.099 -4.791  0.479   0.945   1.532
# log_GOVT_EXP            965.0  2.893  0.238  2.094  2.777   2.938   3.049
#
#                            max
# log_FDI_NET              4.460
# log_TradeOpen            5.934
# log_GDP_per_capita      11.725
# log_CPI_Inflation_rate   4.656
# log_GOVT_EXP             3.336

# %% [markdown]
# - log_FDI_NET: The mean value of log_FDI_NET is 0.909, which indicates that, on average, FDI (Foreign Direct Investment) is positive. However, the standard deviation of 1.237 suggests that there is a considerable amount of variation in FDI. The minimum value of -6.524 suggests that there may be some negative FDI values, which is unusual. The 25th percentile is 0.318, indicating that 25% of the observations have values less than this. The median value is 0.975, which is higher than the mean, indicating a slightly right-skewed distribution. The 75th percentile is 1.581, suggesting that 75% of the observations have values less than this. The maximum value is 4.460, indicating that there may be some extreme values in the dataset.
#
# - log_TradeOpen: The mean value of log_TradeOpen is 4.272, indicating that, on average, countries have a relatively open trade policy. The standard deviation of 0.501 suggests that there is not much variation in the data. The minimum value is 2.761, indicating that some countries may have relatively closed trade policies. The 25th percentile is 3.969, indicating that 25% of the observations have values less than this. The median value is 4.238, which is slightly lower than the mean, indicating a slightly left-skewed distribution. The 75th percentile is 4.595, suggesting that 75% of the observations have values less than this. The maximum value is 5.934, indicating that some countries may have very open trade policies.
#
# - log_GDP_per_capita: The mean value of log_GDP_per_capita is 9.868, indicating that the average GDP per capita of the sample is quite high. The standard deviation of 0.890 suggests that there is a considerable amount of variation in the data. The minimum value is 7.291, indicating that some countries have very low GDP per capita. The 25th percentile is 9.349, indicating that 25% of the observations have values less than this. The median value is 10.047, which is higher than the mean, indicating a slightly right-skewed distribution. The 75th percentile is 10.558, suggesting that 75% of the observations have values less than this. The maximum value is 11.725, indicating that some countries have very high GDP per capita.
#
# - log_CPI_Inflation_rate: The mean value of log_CPI_Inflation_rate is 0.999, indicating that, on average, the inflation rate is positive. The standard deviation of 1.099 suggests that there is a considerable amount of variation in the data. The minimum value is -4.791, indicating that some countries may have experienced deflation. The 25th percentile is 0.479, indicating that 25% of the observations have values less than this. The median value is 0.945, which is lower than the mean, indicating a slightly left-skewed distribution. The 75th percentile is 1.532, suggesting that 75% of the observations have values less than this. The maximum value is 4.656, indicating that some countries may have experienced very high inflation.
#
# - log_GOVT_EXP: The mean value of log_GOVT_EXP is 2.893, indicating that, on average, the government expenditure is relatively low. The standard deviation of 0.238 suggests that there is not much variation in the data. The minimum value is 2.094, indicating that some countries may have very low government expenditure. The 25th percentile is 2.777, indicating that 25% of the observations have values less than this. The median value is 2.938, which is higher than the mean, indicating a slightly right-skewed distribution. The 75th percentile is 3.049, suggesting that 75% of the observations have values less than this. The maximum value is 3.336, indicating that some countries may have relatively high government expenditure.

# %%
skewness = data.skew()
skewness
# Out:
# log_FDI_NET              -0.865662
# log_TradeOpen             0.140460
# log_GDP_per_capita       -0.623778
# log_CPI_Inflation_rate   -0.220232
# log_GOVT_EXP             -0.839800
# dtype: float64

# %% [markdown]
# - log_FDI_NET: The skewness value of -0.866 suggests that the distribution of log_FDI_NET is slightly left-skewed, indicating that there may be some outliers on the left side of the distribution.
#
# - log_TradeOpen: The skewness value of 0.140 indicates that the distribution of log_TradeOpen is approximately symmetric, as the skewness is close to zero.
#
# - log_GDP_per_capita: The skewness value of -0.624 indicates that the distribution of log_GDP_per_capita is slightly left-skewed, indicating that there may be some outliers on the left side of the distribution.
#
# - log_CPI_Inflation_rate: The skewness value of -0.220 suggests that the distribution of log_CPI_Inflation_rate is slightly left-skewed, indicating that there may be some outliers on the left side of the distribution.
#
# - log_GOVT_EXP: The skewness value of -0.840 indicates that the distribution of log_GOVT_EXP is slightly left-skewed, indicating that there may be some outliers on the left side of the distribution.

# %%
kurtosis = data.kurt()
kurtosis
# Out:
# log_FDI_NET               4.058069
# log_TradeOpen             0.410903
# log_GDP_per_capita       -0.232433
# log_CPI_Inflation_rate    2.404744
# log_GOVT_EXP              0.294280
# dtype: float64

# %% [markdown]
# - log_FDI_NET: The kurtosis value of 4.058 suggests that the distribution of log_FDI_NET is leptokurtic, indicating that it has more extreme values (i.e., outliers) than a normal distribution. This means that there may be some observations that are far from the mean.
#
# - log_TradeOpen: The kurtosis value of 0.411 indicates that the distribution of log_TradeOpen is approximately mesokurtic, which means that it has a similar amount of outliers as a normal distribution.
#
# - log_GDP_per_capita: The kurtosis value of -0.232 suggests that the distribution of log_GDP_per_capita is platykurtic, indicating that it has fewer extreme values than a normal distribution.
#
# - log_CPI_Inflation_rate: The kurtosis value of 2.405 indicates that the distribution of log_CPI_Inflation_rate is leptokurtic, indicating that it has more extreme values (i.e., outliers) than a normal distribution. This means that there may be some observations that are far from the mean.
#
# - log_GOVT_EXP: The kurtosis value of 0.294 suggests that the distribution of log_GOVT_EXP is approximately mesokurtic, which means that it has a similar amount of outliers as a normal distribution.

# %%
corr = data.corr().round(3)
corr
# Out:
#                         log_FDI_NET  log_TradeOpen  log_GDP_per_capita
# log_FDI_NET                   1.000          0.510               0.050  \
# log_TradeOpen                 0.510          1.000               0.164
# log_GDP_per_capita            0.050          0.164               1.000
# log_CPI_Inflation_rate       -0.069         -0.179              -0.619
# log_GOVT_EXP                  0.086          0.225               0.344
#
#                         log_CPI_Inflation_rate  log_GOVT_EXP
# log_FDI_NET                             -0.069         0.086
# log_TradeOpen                           -0.179         0.225
# log_GDP_per_capita                      -0.619         0.344
# log_CPI_Inflation_rate                   1.000        -0.263
# log_GOVT_EXP                            -0.263         1.000

# %% [markdown]
# - log_FDI_NET and log_TradeOpen have a moderately positive correlation of 0.51, suggesting that they may be related. This could indicate that a change in log_TradeOpen could be associated with a change in log_FDI_NET, or vice versa.
#
# - log_GDP_per_capita has a weak positive correlation of 0.05 with log_FDI_NET, indicating a minimal relationship between the two variables.
#
# - log_CPI_Inflation_rate has a weak negative correlation of -0.069 with log_FDI_NET, indicating that there may be a slight tendency for higher values of log_CPI_Inflation_rate to be associated with lower values of log_FDI_NET.
#
# - log_GOVT_EXP has a weak positive correlation of 0.086 with log_FDI_NET, suggesting a minor relationship between the two variables.

# %%
fig, ax = plt.subplots(figsize = (10, 8))

# create a heatmap using seaborn
heatmap = sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, ax =ax)

# set rotation for x-axis and y-axis tick labels
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)

# set plot title
plt.title('Correlation')

# show the plot
plt.show()

# %%
data_plot = data.reset_index()
sns.pairplot(data_plot, hue=data_plot.columns[0], palette='bright')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (10, 6))

# Plot the data
data.groupby(level='date').mean().plot(ax = ax)

# Set the title and axis labels
ax.set_title('World Bank Indicators')
ax.set_xlabel('Year')
ax.set_ylabel('Economic Indicator Value')

# Show the plot
plt.show()

# %% [markdown]
# ## ADF Test for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(timeseries):
    
    
    adf_result = adfuller(timeseries)
    adf_stat, pvalue, lags, _, _, _ = adf_result

    print(f'ADF Statistic : {adf_stat:.4}')
    print(f'p-value : {pvalue:.4}')
    print(f'Lags used : {lags}')
    
    if pvalue < 0.05:
        print(f"The ADF test result indicates that the time series is stationary (p-value: {pvalue:.4f})")
    else:
        print(f"The ADF test result indicates that the time series is non-stationary (p-value: {pvalue:.4f})")
        
    return
        
adf_test(data['log_TradeOpen'])
# Out:
# ADF Statistic : -5.438
# p-value : 2.815e-06
# Lags used : 1
# The ADF test result indicates that the time series is stationary (p-value: 0.0000)

# %%
adf_test(data['log_CPI_Inflation_rate'])
# Out:
# ADF Statistic : -11.66
# p-value : 1.929e-21
# Lags used : 1
# The ADF test result indicates that the time series is stationary (p-value: 0.0000)

# %%
adf_test(data['log_GOVT_EXP'])
# Out:
# ADF Statistic : -5.249
# p-value : 6.981e-06
# Lags used : 0
# The ADF test result indicates that the time series is stationary (p-value: 0.0000)

# %%
adf_test(data['log_GDP_per_capita'])
# Out:
# ADF Statistic : -5.875
# p-value : 3.167e-07
# Lags used : 0
# The ADF test result indicates that the time series is stationary (p-value: 0.0000)

# %%
adf_test(data['log_FDI_NET'])
# Out:
# ADF Statistic : -8.342
# p-value : 3.16e-13
# Lags used : 3
# The ADF test result indicates that the time series is stationary (p-value: 0.0000)

# %% [markdown]
# The ADF statistic measures how much the time series deviates from stationarity. The more negative the value, the stronger the evidence against the null hypothesis of non-stationarity. The results suggest strong evidence in favor of stationarity for all the series in the dataset, meaning that the time series is unlikely to have a trend or other non-stationary behavior.

# %% [markdown]
# ### Fixed Effects Model

# %%
from linearmodels.panel import PanelOLS
import statsmodels.api as sm


exog_vars = ['log_FDI_NET', 'log_CPI_Inflation_rate', 'log_TradeOpen', 'log_GOVT_EXP']
exog = sm.add_constant(data[exog_vars])
endog = data['log_GDP_per_capita']

# Fit a fixed effects model
mod = PanelOLS(endog, exog, entity_effects=True, time_effects=False)
res_fe = mod.fit(cov_type='clustered', cluster_entity=True)
print(res_fe.summary)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     log_GDP_per_capita   R-squared:                        0.4395
# Estimator:                   PanelOLS   R-squared (Between):             -0.3119
# No. Observations:                 965   R-squared (Within):               0.4395
# Date:                Wed, May 10 2023   R-squared (Overall):             -0.0959
# Time:                        11:44:50   Log-likelihood                   -306.97
# Cov. Estimator:             Clustered
#                                         F-statistic:                      180.95
# Entities:                          38   P-value                           0.0000
# Avg Obs:                       25.395   Distribution:                   F(4,923)
# Min Obs:                       15.000
# Max Obs:                       30.000   F-statistic (robust):             41.203
#                                         P-value                           0.0000
# ...

# %% [markdown]
# #### with time effects (two-way fixed effects model)

# %%
# Fit a fixed effects model
mod = PanelOLS(endog, exog, entity_effects=True, time_effects=True)
res_te_fe = mod.fit(cov_type='clustered', cluster_entity=True)
print(res_te_fe.summary)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     log_GDP_per_capita   R-squared:                        0.1664
# Estimator:                   PanelOLS   R-squared (Between):             -0.2310
# No. Observations:                 965   R-squared (Within):              -0.1796
# Date:                Wed, May 10 2023   R-squared (Overall):             -0.2279
# Time:                        11:44:50   Log-likelihood                    339.85
# Cov. Estimator:             Clustered
#                                         F-statistic:                      44.627
# Entities:                          38   P-value                           0.0000
# Avg Obs:                       25.395   Distribution:                   F(4,894)
# Min Obs:                       15.000
# Max Obs:                       30.000   F-statistic (robust):             6.4347
#                                         P-value                           0.0000
# ...

# %%
# #tedata = data.set_index(['country','date'])
# #from pandas.stats import plm

# plm.PanelOLS(data['log_FDI_NET'],data[['log_CPI_Inflation_rate', 'log_TradeOpen', 'log_GOVT_EXP']],entity_effects=True)

# %%
data['Predicted GDP_per_capita'] = res_fe.predict()
data['Residuals'] = res_fe.resids

# %%
data['Predicted GDP_per_capita(TE)'] = res_te_fe.predict()
data['Residuals(TE)'] = res_te_fe.resids

# %%
data
# Out:
#                           log_FDI_NET  log_TradeOpen  log_GDP_per_capita
# country       date
# Australia     1990-01-01     0.999070       3.470485            9.811904  \
#               1991-01-01    -0.221546       3.471611            9.844829
#               1992-01-01     0.417461       3.497836            9.832236
#               1993-01-01     0.531775       3.566685            9.781326
#               1994-01-01     0.322917       3.596175            9.805312
# ...                               ...            ...                 ...
# United States 2015-01-01     1.032881       3.325476           10.946635
#               2016-01-01     0.931178       3.280422           10.965898
#               2017-01-01     0.670498       3.306123           11.000561
#               2018-01-01     0.044690       3.318192           11.048081
#               2019-01-01     0.386673       3.275330           11.083993
#
#                           log_CPI_Inflation_rate  log_GOVT_EXP
# ...

# %%
fig, ax = plt.subplots(figsize = (10, 6))

data[['log_GDP_per_capita', 'Predicted GDP_per_capita', 'Predicted GDP_per_capita(TE)']].groupby(level='date').mean().plot(ax = ax)

ax.set_title('Observed GDP Per Capita vrs Predicted GDP Per Capita in OECD Countries')
ax.set_ylabel('Per capita (in billions)')
# Out:
# Text(0, 0.5, 'Per capita (in billions)')

# %%
# plot histogram of residuals
fig, ax = plt.subplots(figsize = (12, 8))
data['Residuals'].plot.hist(bins = 16, ax = ax)

# plot vertical line for mean of residuals
ax.axvline(data['Residuals'].mean(), ls = '--', linewidth = 5, color = 'k')

# %%
# plot histogram of residuals
fig, ax = plt.subplots(figsize = (12, 8))
data['Residuals(TE)'].plot.hist(bins = 16, ax = ax)

# plot vertical line for mean of residuals
ax.axvline(data['Residuals(TE)'].mean(), ls = '--', linewidth = 5, color = 'k')
